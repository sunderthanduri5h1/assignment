# %% [markdown]
# # name :sunder raj
# #roll no :18K41A05H1

# %% [markdown]
# 1. Read mobile dataset using pandas, and preprocess it (fill null values).

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('C:\\Users\\SUNDER\\Desktop\\mobile_cleaned.csv')
df.isnull()
df.fillna(df.mean(),inplace=True)
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(df)
# Out:
#      sim_type  aperture  gpu_rank      weight  stand_by_time  \
# 0           0        12        55  155.000000     250.000000
# 1           0         1        55  132.000000     300.000000
# 2           0         9        55  142.000000     329.000000
# 3           0         8        55  152.000000     385.000000
# 4           1         1        55  234.000000     385.000000
# 5           0        14        55  179.000000     280.000000
# 6           1         1        56  124.000000     230.000000
# 7           0         8        41  154.000000     182.000000
# 8           1         8        41  214.000000     182.000000
# 9           0         1        55  155.000000     435.000000
# 10          0         1        55  169.000000     404.584906
# 11          0        10        55  137.000000     300.000000
# 12          0         1        50  135.000000     280.000000
# 13          0        11        43  133.000000     198.000000
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.max_open_warning':0})
for col in df.columns:
    if (col!='price'):
        df.plot(x=col,y='price')

# %% [markdown]
# after observing all graphs i can say that:
#
# sim_type,Processor,Frames,Sim_size,video_resolution,primary_camera_resolution,ram,internal_memory,screen_pixel_density,version,usb_type,OS is positivey correlated with price. i.e for example if video_resolution increases price increases, similarly if video_resolution decreases price decreases. Thickness,Flash_type,protection,processor_rank is negatively correlated with price. i.e for example if processor_rank increases price decreases similarly if processor_rank decreases price increases. Weight, Stand_by_time,Front_camera,Auto_focus,screen_size,FM,number_of_reviews,talk_Time,height,dispaly_resolution,removable_battery,display_type,brand_rank,number_of_cores,micro_SD_slot,water_proof,width,memory will not change the price.

# %% [markdown]
# 3. Compute outer product of 2 vectors.

# %%
i=[[1,0],[0,1]]
j=[[1,2],[3,4]]
np.outer(i,j)
# Out:
# array([[1, 2, 3, 4],
#        [0, 0, 0, 0],
#        [0, 0, 0, 0],
#        [1, 2, 3, 4]])

# %% [markdown]
# 4.  Write a NumPy program to compute the condition number of a given matrix.

# %%
s=[[1,2],[3,4]]
np.linalg.cond(s)
# Out:
# 14.933034373659268

# %% [markdown]
# 5. write a NumPy program to compute the sum of the diagonal element of a given array(matrix).

# %%
s=[[9,3,8],[1,4,1],[7,9,6]]
np.trace(s)
# Out:
# 19
